# %%
import tensorflow as tf
from tensorflow.keras import layers

# %%
#Import image
batch_size=32
train_data = tf.keras.preprocessing.image_dataset_from_directory("./small_data", validation_split=0.2, subset="training", seed=1, batch_size=batch_size, image_size=(32,32))
val_data = tf.keras.preprocessing.image_dataset_from_directory("./small_data", validation_split=0.2, subset="validation", seed=1, batch_size=batch_size,  image_size=(32,32))
# Out:
# Found 2000 files belonging to 2 classes.
# Using 1600 files for training.
# Found 2000 files belonging to 2 classes.
# Using 400 files for validation.

# %%
class_names = train_data.class_names

# %%
#In case the data is not standardized, standardize it here
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)

AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_data.cache().prefetch(buffer_size=AUTOTUNE)

num_classes = len(class_names)

# %%
#Create model
model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=5
)
# Out:
# Epoch 1/5
# 50/50 [==============================] - 3s 53ms/step - loss: 0.6936 - accuracy: 0.5400 - val_loss: 0.6763 - val_accuracy: 0.6150
# Epoch 2/5
# 50/50 [==============================] - 2s 37ms/step - loss: 0.5446 - accuracy: 0.7269 - val_loss: 0.3473 - val_accuracy: 0.8625
# Epoch 3/5
# 50/50 [==============================] - 2s 40ms/step - loss: 0.3003 - accuracy: 0.8650 - val_loss: 0.2956 - val_accuracy: 0.8950
# Epoch 4/5
# 50/50 [==============================] - 2s 42ms/step - loss: 0.2641 - accuracy: 0.8788 - val_loss: 0.2868 - val_accuracy: 0.8975
# Epoch 5/5
# 50/50 [==============================] - 2s 44ms/step - loss: 0.2344 - accuracy: 0.8838 - val_loss: 0.2546 - val_accuracy: 0.8975

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

#Test images that are in the format of the images that we will actually use
test_folder = "./small_test_data"

for filename in os.listdir(test_folder):
    
    path = os.path.join(test_folder, filename)
    
    img = tf.keras.preprocessing.image.load_img(
        path, target_size=(32, 32)
    )
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    plt.imshow(img)
    plt.show()

    print(
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )
# Out:
# This image most likely belongs to not_circle with a 74.77 percent confidence.
# This image most likely belongs to not_circle with a 99.95 percent confidence.
# This image most likely belongs to circle with a 99.31 percent confidence.
# This image most likely belongs to not_circle with a 69.88 percent confidence.
# This image most likely belongs to not_circle with a 99.81 percent confidence.
# This image most likely belongs to circle with a 70.02 percent confidence.
# This image most likely belongs to not_circle with a 75.76 percent confidence.
# This image most likely belongs to not_circle with a 99.82 percent confidence.
# This image most likely belongs to circle with a 99.88 percent confidence.
# This image most likely belongs to not_circle with a 61.49 percent confidence.
# This image most likely belongs to not_circle with a 99.92 percent confidence.
# This image most likely belongs to circle with a 99.98 percent confidence.
# This image most likely belongs to not_circle with a 71.92 percent confidence.
# This image most likely belongs to not_circle with a 99.60 percent confidence.
# This image most likely belongs to not_circle with a 86.99 percent confidence.
# This image most likely belongs to circle with a 77.66 percent confidence.
# This image most likely belongs to not_circle with a 93.58 percent confidence.
# This image most likely belongs to not_circle with a 84.51 percent confidence.
# This image most likely belongs to not_circle with a 54.13 percent confidence.
# This image most likely belongs to not_circle with a 97.45 percent confidence.
# This image most likely belongs to not_circle with a 72.34 percent confidence.
# This image most likely belongs to not_circle with a 99.84 percent confidence.
# This image most likely belongs to circle with a 99.18 percent confidence.
# This image most likely belongs to circle with a 99.73 percent confidence.
# This image most likely belongs to not_circle with a 99.89 percent confidence.
# This image most likely belongs to not_circle with a 99.57 percent confidence.
# This image most likely belongs to not_circle with a 95.42 percent confidence.
# This image most likely belongs to not_circle with a 68.25 percent confidence.
# This image most likely belongs to not_circle with a 79.60 percent confidence.
# This image most likely belongs to circle with a 100.00 percent confidence.
# This image most likely belongs to circle with a 99.96 percent confidence.
# This image most likely belongs to not_circle with a 95.28 percent confidence.
# This image most likely belongs to not_circle with a 97.61 percent confidence.
# This image most likely belongs to circle with a 99.73 percent confidence.
# This image most likely belongs to circle with a 100.00 percent confidence.
# This image most likely belongs to circle with a 92.18 percent confidence.
# This image most likely belongs to not_circle with a 85.95 percent confidence.
# This image most likely belongs to not_circle with a 75.89 percent confidence.
# This image most likely belongs to circle with a 99.96 percent confidence.
# This image most likely belongs to not_circle with a 99.93 percent confidence.
